# %% [markdown]
# <a href="https://colab.research.google.com/github/Apurbo73/MatplotLib-pyplot/blob/master/MatplotLib_Pyplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
#x and y co-ordinates
xPoints= np.array([0,10])
yPoints= np.array([0,-12])
# plot using pyplot
plt.plot(xPoints,yPoints)
# Displaying the figure:
plt.show()
